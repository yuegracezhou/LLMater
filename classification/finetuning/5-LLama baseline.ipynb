# %%
# import shutil
# shutil.rmtree('/content/content')

# %%
# !unzip /content/results_llama_2.zip
# Out:
# Archive:  /content/results_llama_2.zip
#    creating: content/results/
#   inflating: content/results/test_bace_LLAMA_7_random.csv
#   inflating: content/results/test_bace_LLAMA_7_scaffold.csv
#   inflating: content/results/BACE_train.csv
#   inflating: content/results/test_bace_LLAMA_2_random.log
#   inflating: content/results/BACE_test.csv
#   inflating: content/results/test_bace_LLAMA_2_scaffold.log
#    creating: content/results/zero-shot/
#   inflating: content/results/zero-shot/zero_shot_bace_unsloth_Llama-3.2-3B-Instruct.log
#   inflating: content/results/zero-shot/zero_shot_bace_unsloth_Llama-3.2-3B-Instruct.csv

# %%
import pandas as pd

random2 = pd.read_csv('/content/content/results/test_bace_LLAMA_7_random.csv')
scaffold2 = pd.read_csv('/content/content/results/test_bace_LLAMA_7_scaffold.csv')

# %%
# Encode 'Yes' as 1 and 'No' as 0 in the 'pred' column
random2['pred_encoded'] = random2['pred'].map({'Yes': 1, 'No': 0})
scaffold2['pred_encoded'] = scaffold2['pred'].map({'Yes': 1, 'No': 0})

# %%
results = []
results.append(['mode','accuracy','precision','recall','f1'])
results
# Out:
# [['mode', 'accuracy', 'precision', 'recall', 'f1']]

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_test = random2['class_label']
y_pred = random2['pred_encoded']

# Combine y_test and y_pred into a temporary DataFrame to easily drop rows with NaNs
temp_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
temp_df = temp_df.dropna()

# Update y_test and y_pred with the cleaned data
y_test = temp_df['y_test']
y_pred = temp_df['y_pred']



# Evaluate the predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
results.append(['random2',accuracy,precision,recall,f1])

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.5500
# Precision: 0.0000
# Recall: 0.0000
# F1-score: 0.0000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_test = scaffold2['class_label']
y_pred = scaffold2['pred_encoded']

# Combine y_test and y_pred into a temporary DataFrame to easily drop rows with NaNs
temp_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
temp_df = temp_df.dropna()

# Update y_test and y_pred with the cleaned data
y_test = temp_df['y_test']
y_pred = temp_df['y_pred']



# Evaluate the predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
results.append(['scaffold2',accuracy,precision,recall,f1])

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.5100
# Precision: 0.1000
# Recall: 0.0111
# F1-score: 0.0200

# %%
# !unzip /content/results_llama_4.zip
# Out:
# Archive:  /content/results_llama_4.zip
# replace content/results/test_bace_LLAMA_7_random.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: content/results/test_bace_LLAMA_7_random.csv
#   inflating: content/results/test_bace_LLAMA_7_scaffold.csv
#   inflating: content/results/BACE_train.csv
#   inflating: content/results/test_bace_LLAMA_2_random.log
#   inflating: content/results/BACE_test.csv
#   inflating: content/results/test_bace_LLAMA_2_scaffold.log
#   inflating: content/results/zero-shot/zero_shot_bace_unsloth_Llama-3.2-3B-Instruct.log
#   inflating: content/results/zero-shot/zero_shot_bace_unsloth_Llama-3.2-3B-Instruct.csv
#   inflating: content/results/test_bace_LLAMA_4_random.csv
#   inflating: content/results/test_bace_LLAMA_4_random.log
#   inflating: content/results/test_bace_LLAMA_4_scaffold.csv
#   inflating: content/results/test_bace_LLAMA_4_scaffold.log

# %%
import pandas as pd

random4 = pd.read_csv('/content/content/results/test_bace_LLAMA_4_random.csv')
scaffold4 = pd.read_csv('/content/content/results/test_bace_LLAMA_4_scaffold.csv')

# %%
# Encode 'Yes' as 1 and 'No' as 0 in the 'pred' column
random4['pred_encoded'] = random4['pred'].map({'Yes': 1, 'No': 0})
scaffold4['pred_encoded'] = scaffold4['pred'].map({'Yes': 1, 'No': 0})

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_test = random4['class_label']
y_pred = random4['pred_encoded']

# Combine y_test and y_pred into a temporary DataFrame to easily drop rows with NaNs
temp_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
temp_df = temp_df.dropna()

# Update y_test and y_pred with the cleaned data
y_test = temp_df['y_test']
y_pred = temp_df['y_pred']



# Evaluate the predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
results.append(['random4',accuracy,precision,recall,f1])

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.5500
# Precision: 0.0000
# Recall: 0.0000
# F1-score: 0.0000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_test = scaffold4['class_label']
y_pred = scaffold4['pred_encoded']

# Combine y_test and y_pred into a temporary DataFrame to easily drop rows with NaNs
temp_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
temp_df = temp_df.dropna()

# Update y_test and y_pred with the cleaned data
y_test = temp_df['y_test']
y_pred = temp_df['y_pred']



# Evaluate the predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
results.append(['scaffold4',accuracy,precision,recall,f1])

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.5350
# Precision: 0.2857
# Recall: 0.0222
# F1-score: 0.0412

# %%
# !unzip /content/results_llama_8.zip
# Out:
# Archive:  /content/results_llama_8.zip
# replace content/results/test_bace_LLAMA_7_random.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: content/results/test_bace_LLAMA_7_random.csv
#   inflating: content/results/test_bace_LLAMA_7_scaffold.csv
#   inflating: content/results/BACE_train.csv
#   inflating: content/results/test_bace_LLAMA_2_random.log
#   inflating: content/results/BACE_test.csv
#   inflating: content/results/test_bace_LLAMA_2_scaffold.log
#   inflating: content/results/zero-shot/zero_shot_bace_unsloth_Llama-3.2-3B-Instruct.log
#   inflating: content/results/zero-shot/zero_shot_bace_unsloth_Llama-3.2-3B-Instruct.csv
#   inflating: content/results/test_bace_LLAMA_4_random.csv
#   inflating: content/results/test_bace_LLAMA_4_random.log
#   inflating: content/results/test_bace_LLAMA_4_scaffold.csv
#   inflating: content/results/test_bace_LLAMA_4_scaffold.log
#   inflating: content/results/test_bace_LLAMA_8_random.log
# ...

# %%
import pandas as pd

random8 = pd.read_csv('/content/content/results/test_bace_LLAMA_8_random.csv')
scaffold8 = pd.read_csv('/content/content/results/test_bace_LLAMA_8_scaffold.csv')

# %%
# Encode 'Yes' as 1 and 'No' as 0 in the 'pred' column
random8['pred_encoded'] = random8['pred'].map({'Yes': 1, 'No': 0})
scaffold8['pred_encoded'] = scaffold8['pred'].map({'Yes': 1, 'No': 0})

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_test = random8['class_label']
y_pred = random8['pred_encoded']

# Combine y_test and y_pred into a temporary DataFrame to easily drop rows with NaNs
temp_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
temp_df = temp_df.dropna()

# Update y_test and y_pred with the cleaned data
y_test = temp_df['y_test']
y_pred = temp_df['y_pred']



# Evaluate the predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
results.append(['random8',accuracy,precision,recall,f1])

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.5500
# Precision: 0.5402
# Recall: 0.9038
# F1-score: 0.6763

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_test = scaffold8['class_label']
y_pred = scaffold8['pred_encoded']

# Combine y_test and y_pred into a temporary DataFrame to easily drop rows with NaNs
temp_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
temp_df = temp_df.dropna()

# Update y_test and y_pred with the cleaned data
y_test = temp_df['y_test']
y_pred = temp_df['y_pred']



# Evaluate the predictions
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
results.append(['scaffold8',accuracy,precision,recall,f1])

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.5979
# Precision: 0.5852
# Recall: 0.7822
# F1-score: 0.6695

# %%
df = pd.DataFrame(results[1:], columns=results[0])
df
# Out:
#         mode  accuracy  precision    recall        f1
# 0    random2  0.550000   0.000000  0.000000  0.000000
# 1  scaffold2  0.510000   0.100000  0.011111  0.020000
# 2    random4  0.550000   0.000000  0.000000  0.000000
# 3  scaffold4  0.535000   0.285714  0.022222  0.041237
# 4    random8  0.550000   0.540230  0.903846  0.676259
# 5  scaffold8  0.597938   0.585185  0.782178  0.669492
